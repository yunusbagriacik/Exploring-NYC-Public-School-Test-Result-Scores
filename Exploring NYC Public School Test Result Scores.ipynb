# %%
# Re-run this cell 
import pandas as pd

# Read in the data
schools = pd.read_csv("datasets/Exploring NYC Public School Test Result Scores/schools.csv")

# Preview the data
schools
# Out:
#                                            school_name    borough  \
# 0    New Explorations into Science, Technology and ...  Manhattan
# 1                                 Essex Street Academy  Manhattan
# 2                         Lower Manhattan Arts Academy  Manhattan
# 3      High School for Dual Language and Asian Studies  Manhattan
# 4        Henry Street School for International Studies  Manhattan
# ..                                                 ...        ...
# 370  Queens High School for Information, Research, ...     Queens
# 371  Rockaway Park High School for Environmental Su...     Queens
# 372                   Channel View School for Research     Queens
# 373                    Rockaway Collegiate High School     Queens
# 374                                  Scholars' Academy     Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 0            M022           657              601              601
# ...

# %%
schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school_name      375 non-null    object
#  1   borough          375 non-null    object
#  2   building_code    375 non-null    object
#  3   average_math     375 non-null    int64
#  4   average_reading  375 non-null    int64
#  5   average_writing  375 non-null    int64
#  6   percent_tested   355 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 20.6+ KB

# %%
schools.describe()
# Out:
#        average_math  average_reading  average_writing  percent_tested
# count    375.000000       375.000000       375.000000      355.000000
# mean     432.944000       424.504000       418.458667       64.976338
# std       71.952373        61.881069        64.548599       18.747634
# min      317.000000       302.000000       284.000000       18.500000
# 25%      386.000000       386.000000       382.000000       50.950000
# 50%      415.000000       413.000000       403.000000       64.800000
# 75%      458.500000       445.000000       437.500000       79.600000
# max      754.000000       697.000000       693.000000      100.000000

# %%
school_math = schools[["school_name", "average_math"]]
threshold_score = 0.85 * school_math["average_math"].max()
best_math_schools = sorted_school_math[sorted_school_math["average_math"]>=threshold_score].sort_values("average_math",ascending = False)
best_math_schools
# Out:
#                                            school_name  average_math
# 88                              Stuyvesant High School           754
# 170                       Bronx High School of Science           714
# 93                 Staten Island Technical High School           711
# 365  Queens High School for the Sciences at York Co...           701
# 68   High School for Mathematics, Science, and Engi...           683
# 280                     Brooklyn Technical High School           682
# 333                        Townsend Harris High School           680
# 174  High School of American Studies at Lehman College           669
# 0    New Explorations into Science, Technology and ...           657
# 45                       Eleanor Roosevelt High School           641

# %%
avg_math_reading_writing = schools[["school_name","average_math","average_reading","average_writing"]]
schools["total_SAT"] = schools["average_math"] + schools["average_reading"] + schools["average_writing"]
avg_math_reading_writing = schools[["school_name", "total_SAT"]]
top_10_schools = avg_math_reading_writing.sort_values("total_SAT",ascending = False).head(10)
top_10_schools
# Out:
#                                            school_name  total_SAT
# 88                              Stuyvesant High School       2144
# 170                       Bronx High School of Science       2041
# 93                 Staten Island Technical High School       2041
# 174  High School of American Studies at Lehman College       2013
# 333                        Townsend Harris High School       1981
# 365  Queens High School for the Sciences at York Co...       1947
# 5                       Bard High School Early College       1914
# 280                     Brooklyn Technical High School       1896
# 45                       Eleanor Roosevelt High School       1889
# 68   High School for Mathematics, Science, and Engi...       1889

# %%
num_schools = schools.groupby("borough")["school_name"].count()
num_schools = num_schools.reset_index()
num_schools
# Out:
#          borough  school_name
# 0          Bronx           98
# 1       Brooklyn          109
# 2      Manhattan           89
# 3         Queens           69
# 4  Staten Island           10

# %%
schools["total_SAT"].sum()
# Out:
# 478465

# %%
largest_std_dev = schools.groupby("borough").agg(
    num_schools=("school_name", "count"),
    std_SAT=("total_SAT", "std"),
    average_SAT=("total_SAT", "mean")
).round(2)
largest_std_dev = largest_std_dev.sort_values("std_SAT",ascending=False).head(1)
largest_std_dev
# Out:
#            num_schools  std_SAT  average_SAT
# borough
# Manhattan           89   230.29      1340.13
